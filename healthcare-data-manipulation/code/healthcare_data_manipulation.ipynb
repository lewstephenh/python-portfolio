# %% [markdown]
# ## healthcare_data_manipulation.ipnyb
#
# This program extracts synthetic healthcare data from a database stored on SQL Server and Snowflake. It then manipulates the data in various ways.
#
# Written by Stephen Lew

# %%
import os
import pyodbc
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %% [markdown]
# ### Load environment variables from .env file

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Extract data from database stored on SQL Server
#
# Use a **user-defined function** and an **f-string** to make the process easier to understand.

# %%
def mssql_engine(server, database):
    engine = create_engine(
        f"mssql+pyodbc://{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&Trusted_Connection=yes"
    )
    return engine

engine1 = mssql_engine(server = "localhost\\SQLEXPRESS",
                       database = "SyntheticHealthcareData")

# %% [markdown]
# Synthetic healthcare claims data
#
# Source: https://www.kaggle.com/datasets/abuthahir1998/synthetic-healthcare-claims-dataset/data

# %%
df_claim_data = pd.read_sql("SELECT * FROM claim_data", engine1)
df_claim_data.head(5)
# Out:
#      claim_id provider_id  patient_id date_of_service  billed_amount  \
# 0  0HO1FSN4AP  0126528997  7936697103      2024-08-07          304.0
# 1  9U86CI2P5A  6986719948  1547160031      2024-06-21          348.0
# 2  1QEU1AIDAU  1355108115  2611585318      2024-07-04          235.0
# 3  WH7XDS8CEO  9991055906  7167948632      2024-05-26          112.0
# 4  M6OJEZ8KGI  7382167012  2140226267      2024-07-16          406.0
#
#   procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 0          99231          A02.1           218.0        203.0       Self-Pay
# 1          99213       T40.905A           216.0        206.0       Medicare
# 2          99213          A00.1           148.0        119.0     Commercial
# 3          99215          A18.6            79.0         69.0       Medicare
# 4          99238          A17.9           320.0        259.0       Medicare
#
#    claim_status                    reason_code followup_required  \
# 0          Paid  Incorrect billing information               Yes
# 1          Paid         Pre-existing condition               Yes
# 2  Under Review                Duplicate claim                No
# 3        Denied     Authorization not obtained                No
# 4        Denied     Authorization not obtained                No
#
#         ar_status         outcome
# 0         Pending  Partially Paid
# 1            Open          Denied
# 2          Denied          Denied
# 3  Partially Paid          Denied
# 4         On Hold          Denied

# %% [markdown]
# ICD 10 code descriptions
#
# Source: https://www.kaggle.com/datasets/mrhell/icd10cm-codeset-2023

# %%
df_icd_codes = pd.read_sql("SELECT * FROM icd_codes", engine1)
df_icd_codes.head(5)
# Out:
#   icd_code                                        description
# 0    A00.0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1    A00.1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2    A00.9                               Cholera, unspecified
# 3   A01.00                         Typhoid fever, unspecified
# 4   A01.01                                 Typhoid meningitis

# %% [markdown]
# ### Extract data from database stored on Snowflake
#
# Use a **user-defined function** and an **f-string** to make the process easier to understand.

# %%
def snowflake_engine(uid, pwd, account, database, schema):
    engine = create_engine(
        f"snowflake://{uid}:{pwd}@{account}/{database}/{schema}?warehouse=COMPUTE_WH&role=ACCOUNTADMIN"
    )

    return engine

engine2 = snowflake_engine(uid = os.getenv("SNOWFLAKE_USER"),
                           pwd = os.getenv("SNOWFLAKE_PASSWORD"),
                           account = os.getenv("SNOWFLAKE_ACCOUNT"),
                           database = "SYNTHETICHEALTHCAREDATA",
                           schema = "PUBLIC")

# %%
del df_claim_data
df_claim_data = pd.read_sql("SELECT * FROM claim_data", engine2)
df_claim_data.head(5)
# Out:
#      claim_id provider_id  patient_id date_of_service  billed_amount  \
# 0  0HO1FSN4AP  0126528997  7936697103      2024-08-07          304.0
# 1  9U86CI2P5A  6986719948  1547160031      2024-06-21          348.0
# 2  1QEU1AIDAU  1355108115  2611585318      2024-07-04          235.0
# 3  WH7XDS8CEO  9991055906  7167948632      2024-05-26          112.0
# 4  M6OJEZ8KGI  7382167012  2140226267      2024-07-16          406.0
#
#   procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 0          99231          A02.1           218.0        203.0       Self-Pay
# 1          99213       T40.905A           216.0        206.0       Medicare
# 2          99213          A00.1           148.0        119.0     Commercial
# 3          99215          A18.6            79.0         69.0       Medicare
# 4          99238          A17.9           320.0        259.0       Medicare
#
#    claim_status                    reason_code followup_required  \
# 0          Paid  Incorrect billing information               Yes
# 1          Paid         Pre-existing condition               Yes
# 2  Under Review                Duplicate claim                No
# 3        Denied     Authorization not obtained                No
# 4        Denied     Authorization not obtained                No
#
#         ar_status         outcome
# 0         Pending  Partially Paid
# 1            Open          Denied
# 2          Denied          Denied
# 3  Partially Paid          Denied
# 4         On Hold          Denied

# %%
del df_icd_codes
df_icd_codes = pd.read_sql("SELECT * FROM icd_codes", engine2)
df_icd_codes.head(5)
# Out:
#   icd_code                                        description
# 0    A00.0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1    A00.1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2    A00.9                               Cholera, unspecified
# 3   A01.00                         Typhoid fever, unspecified
# 4   A01.01                                 Typhoid meningitis

# %% [markdown]
# ### Join tables and rename field
#
# Bring in descriptions of ICD-10 codes into the claims data.
#
# Rename the new field from "description" to "diagnosis description".

# %%
df_claim_data = (df_claim_data.merge(df_icd_codes, left_on = "diagnosis_code", right_on = "icd_code", how = "left")
                 .rename(columns = {"description": "diagnosis_description"})
                 .drop("icd_code", axis = 1))
df_claim_data.head(5)
# Out:
#      claim_id provider_id  patient_id date_of_service  billed_amount  \
# 0  0HO1FSN4AP  0126528997  7936697103      2024-08-07          304.0
# 1  9U86CI2P5A  6986719948  1547160031      2024-06-21          348.0
# 2  1QEU1AIDAU  1355108115  2611585318      2024-07-04          235.0
# 3  WH7XDS8CEO  9991055906  7167948632      2024-05-26          112.0
# 4  M6OJEZ8KGI  7382167012  2140226267      2024-07-16          406.0
#
#   procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 0          99231          A02.1           218.0        203.0       Self-Pay
# 1          99213       T40.905A           216.0        206.0       Medicare
# 2          99213          A00.1           148.0        119.0     Commercial
# 3          99215          A18.6            79.0         69.0       Medicare
# 4          99238          A17.9           320.0        259.0       Medicare
#
#    claim_status                    reason_code followup_required  \
# 0          Paid  Incorrect billing information               Yes
# 1          Paid         Pre-existing condition               Yes
# 2  Under Review                Duplicate claim                No
# 3        Denied     Authorization not obtained                No
# 4        Denied     Authorization not obtained                No
#
#         ar_status         outcome  \
# 0         Pending  Partially Paid
# 1            Open          Denied
# 2          Denied          Denied
# 3  Partially Paid          Denied
# 4         On Hold          Denied
#
#                                diagnosis_description
# 0                                  Salmonella sepsis
# 1  Adverse effect of unspecified psychodysleptics...
# 2    Cholera due to Vibrio cholerae 01, biovar eltor
# 3               Tuberculosis of (inner) (middle) ear
# 4        Tuberculosis of nervous system, unspecified

# %% [markdown]
# ### Create variable and summarise data
#
# Create a new dataframe that has, for each insurance type, the rate at which claims are denied.

# %%
df_claim_data["denial_rate"] = np.where(df_claim_data["claim_status"] == "Denied", 100, 0)
df_denial_rate = (df_claim_data.groupby("insurance_type")["denial_rate"].mean()
                  .reset_index())
df_denial_rate
# Out:
#   insurance_type  denial_rate
# 0     Commercial    34.362934
# 1       Medicaid    28.957529
# 2       Medicare    36.051502
# 3       Self-Pay    32.128514

# %% [markdown]
# ### Filter data
#
# Subset the data to only records with a diagnosis code of A05.4 (Foodborne Bacillus cereus intoxication).

# %%
df_filter = df_claim_data.query("diagnosis_code == 'A05.4'")
df_filter.head(5)
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 8    TLU7MTJ63J  6675789567  1861061750      2024-07-16          126.0
# 59   Y4I4JQPVK4  8925429111  9342177346      2024-07-11          267.0
# 213  TD0EG8I93R  6744823555  6194960851      2024-08-17          349.0
# 253  RS1YY0WY24  5431725002  9176601831      2024-05-28          111.0
# 263  BADGAN63O1  0456145390  9008471630      2024-07-25          172.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 8            99238          A05.4           109.0        108.0       Medicare
# 59           99215          A05.4           214.0        171.0       Self-Pay
# 213          99231          A05.4           273.0        267.0     Commercial
# 253          99238          A05.4            81.0         76.0       Self-Pay
# 263          99222          A05.4           147.0        127.0       Medicare
#
#      claim_status                    reason_code followup_required  \
# 8          Denied     Authorization not obtained                No
# 59   Under Review     Authorization not obtained               Yes
# 213          Paid            Service not covered                No
# 253          Paid      Lack of medical necessity               Yes
# 263  Under Review  Incorrect billing information               Yes
#
#           ar_status         outcome                   diagnosis_description  \
# 8            Closed  Partially Paid  Foodborne Bacillus cereus intoxication
# 59             Open            Paid  Foodborne Bacillus cereus intoxication
# 213  Partially Paid  Partially Paid  Foodborne Bacillus cereus intoxication
# 253          Closed          Denied  Foodborne Bacillus cereus intoxication
# 263            Open            Paid  Foodborne Bacillus cereus intoxication
#
#      denial_rate
# 8            100
# 59             0
# 213            0
# 253            0
# 263            0

# %% [markdown]
# ### Sort data
#
# Sort data by date of service then claim ID.

# %%
(df_claim_data.sort_values(["date_of_service", "claim_id"])
 .head(5))
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 235  4AECRPPSTL  6034872297  1183596686      2024-05-01          214.0
# 403  8H6FAKD1OH  1109442085  5127757508      2024-05-01          244.0
# 267  AFCVL9N05Z  0369668919  3458366761      2024-05-01          108.0
# 919  WR6QACIBSK  6636473801  6871324728      2024-05-01          252.0
# 174  0APP6HH8P5  5577749071  8116288647      2024-05-02          224.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 235          99213          M72.8           179.0        178.0     Commercial
# 403          99238          A04.8           168.0        150.0       Medicaid
# 267          99222          A05.0            66.0         58.0       Medicaid
# 919          99213        M93.259           222.0        183.0     Commercial
# 174          99221          A05.3           158.0        133.0     Commercial
#
#      claim_status                reason_code followup_required  \
# 235  Under Review            Duplicate claim                No
# 403  Under Review            Duplicate claim               Yes
# 267          Paid      Missing documentation               Yes
# 919          Paid            Duplicate claim               Yes
# 174        Denied  Lack of medical necessity               Yes
#
#           ar_status         outcome  \
# 235  Partially Paid  Partially Paid
# 403         Pending            Paid
# 267          Closed  Partially Paid
# 919          Denied  Partially Paid
# 174            Open            Paid
#
#                                diagnosis_description  denial_rate
# 235                     Other fibroblastic disorders            0
# 403  Other specified bacterial intestinal infections            0
# 267            Foodborne staphylococcal intoxication            0
# 919       Osteochondritis dissecans, unspecified hip            0
# 174   Foodborne Vibrio parahaemolyticus intoxication          100

# %% [markdown]
# ### Keep select fields
#
# Keep only the fields for claim ID, procedure code, and diagnosis code.

# %%
df_select = df_claim_data[["claim_id", "procedure_code", "diagnosis_code"]]
df_select.head(5)
# Out:
#      claim_id procedure_code diagnosis_code
# 0  0HO1FSN4AP          99231          A02.1
# 1  9U86CI2P5A          99213       T40.905A
# 2  1QEU1AIDAU          99213          A00.1
# 3  WH7XDS8CEO          99215          A18.6
# 4  M6OJEZ8KGI          99238          A17.9

# %% [markdown]
# ### Perform the same operation on multiple columns
#
# For each field insurance_type, claim_status, reason_code, followup_required, ar_status, and outcome, create a new field with the value in uppercase.
#
# Use a **for loop** with **tuple unpacking** and **f-strings**.

# %%
list_chr_vars = [
    ("insurance_type", "insurance_type_upcase"),
    ("claim_status", "claim_status_upcase"),
    ("reason_code", "reason_code_upcase"),
    ("followup_required", "followup_required_upcase"),
    ("ar_status", "ar_status_upcase"),
    ("outcome", "outcome_upcase")
]
for mcase, ucase in list_chr_vars:
    df_claim_data[f"{ucase}"] = df_claim_data[f"{mcase}"].str.upper()
df_claim_data.head(5)
# Out:
#      claim_id provider_id  patient_id date_of_service  billed_amount  \
# 0  0HO1FSN4AP  0126528997  7936697103      2024-08-07          304.0
# 1  9U86CI2P5A  6986719948  1547160031      2024-06-21          348.0
# 2  1QEU1AIDAU  1355108115  2611585318      2024-07-04          235.0
# 3  WH7XDS8CEO  9991055906  7167948632      2024-05-26          112.0
# 4  M6OJEZ8KGI  7382167012  2140226267      2024-07-16          406.0
#
#   procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 0          99231          A02.1           218.0        203.0       Self-Pay
# 1          99213       T40.905A           216.0        206.0       Medicare
# 2          99213          A00.1           148.0        119.0     Commercial
# 3          99215          A18.6            79.0         69.0       Medicare
# 4          99238          A17.9           320.0        259.0       Medicare
#
#    ...       ar_status         outcome  \
# 0  ...         Pending  Partially Paid
# 1  ...            Open          Denied
# 2  ...          Denied          Denied
# 3  ...  Partially Paid          Denied
# 4  ...         On Hold          Denied
#
#                                diagnosis_description denial_rate  \
# 0                                  Salmonella sepsis           0
# 1  Adverse effect of unspecified psychodysleptics...           0
# 2    Cholera due to Vibrio cholerae 01, biovar eltor           0
# 3               Tuberculosis of (inner) (middle) ear         100
# 4        Tuberculosis of nervous system, unspecified         100
#
#   insurance_type_upcase claim_status_upcase             reason_code_upcase  \
# 0              SELF-PAY                PAID  INCORRECT BILLING INFORMATION
# 1              MEDICARE                PAID         PRE-EXISTING CONDITION
# 2            COMMERCIAL        UNDER REVIEW                DUPLICATE CLAIM
# 3              MEDICARE              DENIED     AUTHORIZATION NOT OBTAINED
# 4              MEDICARE              DENIED     AUTHORIZATION NOT OBTAINED
#
#   followup_required_upcase ar_status_upcase  outcome_upcase
# 0                      YES          PENDING  PARTIALLY PAID
# 1                      YES             OPEN          DENIED
# 2                       NO           DENIED          DENIED
# 3                       NO   PARTIALLY PAID          DENIED
# 4                       NO          ON HOLD          DENIED
#
# [5 rows x 23 columns]
