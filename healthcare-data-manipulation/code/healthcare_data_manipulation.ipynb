# %% [markdown]
# ## healthcare_data_manipulation.ipnyb
#
# This program extracts synthetic healthcare data from a database stored on SQL Server and manipulates it in various ways.
#
# Written by Stephen Lew

# %%
import pyodbc
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract data from database stored on SQL Server

# %%
engine = create_engine(
    "mssql+pyodbc://localhost\\SQLEXPRESS/SyntheticHealthcareData?driver=ODBC+Driver+17+for+SQL+Server&Trusted_Connection=yes"
)

# %% [markdown]
# Synthetic healthcare claims data
#
# Source: https://www.kaggle.com/datasets/abuthahir1998/synthetic-healthcare-claims-dataset/data

# %%
df_claim_data = pd.read_sql("SELECT * FROM claim_data", engine)
df_claim_data.sample(5)
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 236  DZFSOUHGBF  3284140919  7714365852      2024-06-27          135.0
# 833  A25OXEV0JO  9122941551  8439672012      2024-07-09          269.0
# 570  FKTZG0CNQO  5629941385  3025164227      2024-08-16          326.0
# 535  CLT90VMN8P  6079651870  5818045824      2024-09-09          316.0
# 905  QCXU5JFFML  4857852547  4151838566      2024-07-25          220.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 236          99221       R40.2331           107.0         88.0       Medicaid
# 833          99231          A07.9           186.0        154.0     Commercial
# 570          99231          A04.5           269.0        240.0     Commercial
# 535          99233         O88.33           278.0        228.0       Medicare
# 905          99233          A01.4           162.0        139.0       Medicare
#
#      claim_status                    reason_code followup_required  \
# 236  Under Review         Pre-existing condition               Yes
# 833  Under Review  Incorrect billing information                No
# 570          Paid          Missing documentation                No
# 535          Paid         Pre-existing condition                No
# 905        Denied         Pre-existing condition                No
#
#           ar_status         outcome
# 236         Pending          Denied
# 833            Open            Paid
# 570         On Hold            Paid
# 535  Partially Paid            Paid
# 905            Open  Partially Paid

# %% [markdown]
# ICD 10 code descriptions
#
# Source: https://www.kaggle.com/datasets/mrhell/icd10cm-codeset-2023

# %%
df_icd_codes = pd.read_sql("SELECT * FROM icd_codes", engine)
df_icd_codes.sample(5)
# Out:
#        icd_code                                        description
# 71356  Y36.330S  War operations involving flamethrower, militar...
# 38340  S59.901D  Unspecified injury of right elbow, subsequent ...
# 24158  S00.219S  Abrasion of unspecified eyelid and periocular ...
# 40658  S62.366S  Nondisplaced fracture of neck of fifth metacar...
# 39719  S62.132P  Displaced fracture of capitate [os magnum] bon...

# %% [markdown]
# ### Join data
#
# Bring in descriptions of ICD-10 codes into the claims data.
#
# Rename the new field from "description" to "diagnosis description".

# %%
df_claim_data = (df_claim_data.merge(df_icd_codes, left_on = "diagnosis_code", right_on = "icd_code", how = "left")
                 .rename(columns = {"description": "diagnosis_description"})
                 .drop("icd_code", axis = 1))
df_claim_data.sample(5)
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 131  I3W13NNO8Q  6763652717  7851510784      2024-07-15          359.0
# 841  IDINVUDJGV  5145102885  0413266303      2024-07-30          212.0
# 107  OJFM3JQZ1S  2285909913  0853961177      2024-05-18          303.0
# 229  IJ5T168FLX  7864007404  7250117317      2024-05-06          267.0
# 373  AZLH3XYRRW  8105376676  4316744945      2024-06-12          395.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 131          99233          A04.1           303.0        276.0       Medicare
# 841          99233          A01.2           143.0        122.0       Medicaid
# 107          99215          A04.1           230.0        222.0       Self-Pay
# 229          99222          A19.9           221.0        182.0       Medicaid
# 373          99232          A03.3           342.0        288.0       Medicare
#
#      claim_status                 reason_code followup_required  \
# 131        Denied  Authorization not obtained                No
# 841  Under Review  Authorization not obtained                No
# 107          Paid  Patient eligibility issues               Yes
# 229  Under Review         Service not covered               Yes
# 373  Under Review  Patient eligibility issues               Yes
#
#           ar_status         outcome  \
# 131         On Hold            Paid
# 841          Denied  Partially Paid
# 107         Pending            Paid
# 229  Partially Paid          Denied
# 373            Open  Partially Paid
#
#                           diagnosis_description
# 131  Enterotoxigenic Escherichia coli infection
# 841                         Paratyphoid fever B
# 107  Enterotoxigenic Escherichia coli infection
# 229           Miliary tuberculosis, unspecified
# 373          Shigellosis due to Shigella sonnei

# %% [markdown]
# ### Create variable and aggregate data
#
# Create a new dataframe that has, for each insurance type, the rate at which claims are denied.

# %%
df_claim_data["denial_rate"] = np.where(df_claim_data["claim_status"] == "Denied", 100, 0)
df_denial_rate = (df_claim_data.groupby("insurance_type")["denial_rate"].mean()
                  .reset_index())
print(df_denial_rate)
# Out:
#   insurance_type  denial_rate
# 0     Commercial    34.362934
# 1       Medicaid    28.957529
# 2       Medicare    36.051502
# 3       Self-Pay    32.128514

# %% [markdown]
# ### Filter data
#
# Subset the data to only records with a diagnosis code of A05.4 (Foodborne Bacillus cereus intoxication).

# %%
df_filter = df_claim_data.query("diagnosis_code == 'A05.4'")
df_filter.sample(5)
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 745  6O1LURCE9Z  2352266822  1246918644      2024-06-02          365.0
# 475  DX78LUNF87  2316904587  9259142711      2024-06-30          492.0
# 600  S1SUBLMW4D  9685974415  3445672900      2024-09-16          151.0
# 417  EYOS09JPEW  3050607331  6787726636      2024-09-12          193.0
# 720  ALIEYHSV55  8958518789  1059063310      2024-06-17          434.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 745          99232          A05.4           254.0        204.0       Self-Pay
# 475          99238          A05.4           379.0        352.0       Self-Pay
# 600          99213          A05.4            92.0         75.0       Medicaid
# 417          99215          A05.4           148.0        146.0       Medicaid
# 720          99223          A05.4           385.0        384.0     Commercial
#
#      claim_status                    reason_code followup_required  \
# 745          Paid  Incorrect billing information                No
# 475  Under Review      Lack of medical necessity                No
# 600        Denied         Pre-existing condition               Yes
# 417        Denied          Missing documentation                No
# 720        Denied            Service not covered               Yes
#
#           ar_status         outcome                   diagnosis_description  \
# 745         On Hold            Paid  Foodborne Bacillus cereus intoxication
# 475          Closed            Paid  Foodborne Bacillus cereus intoxication
# 600  Partially Paid            Paid  Foodborne Bacillus cereus intoxication
# 417         Pending  Partially Paid  Foodborne Bacillus cereus intoxication
# 720            Open            Paid  Foodborne Bacillus cereus intoxication
#
#      denial_rate
# 745            0
# 475            0
# 600          100
# 417          100
# 720          100

# %% [markdown]
# ### Sort data
#
# Sort data by date of service then claim ID.

# %%
(df_claim_data.sort_values(["date_of_service", "claim_id"])
 .head(5))
# Out:
#        claim_id provider_id  patient_id date_of_service  billed_amount  \
# 235  4AECRPPSTL  6034872297  1183596686      2024-05-01          214.0
# 403  8H6FAKD1OH  1109442085  5127757508      2024-05-01          244.0
# 267  AFCVL9N05Z  0369668919  3458366761      2024-05-01          108.0
# 919  WR6QACIBSK  6636473801  6871324728      2024-05-01          252.0
# 174  0APP6HH8P5  5577749071  8116288647      2024-05-02          224.0
#
#     procedure_code diagnosis_code  allowed_amount  paid_amount insurance_type  \
# 235          99213          M72.8           179.0        178.0     Commercial
# 403          99238          A04.8           168.0        150.0       Medicaid
# 267          99222          A05.0            66.0         58.0       Medicaid
# 919          99213        M93.259           222.0        183.0     Commercial
# 174          99221          A05.3           158.0        133.0     Commercial
#
#      claim_status                reason_code followup_required  \
# 235  Under Review            Duplicate claim                No
# 403  Under Review            Duplicate claim               Yes
# 267          Paid      Missing documentation               Yes
# 919          Paid            Duplicate claim               Yes
# 174        Denied  Lack of medical necessity               Yes
#
#           ar_status         outcome  \
# 235  Partially Paid  Partially Paid
# 403         Pending            Paid
# 267          Closed  Partially Paid
# 919          Denied  Partially Paid
# 174            Open            Paid
#
#                                diagnosis_description  denial_rate
# 235                     Other fibroblastic disorders            0
# 403  Other specified bacterial intestinal infections            0
# 267            Foodborne staphylococcal intoxication            0
# 919       Osteochondritis dissecans, unspecified hip            0
# 174   Foodborne Vibrio parahaemolyticus intoxication          100

# %% [markdown]
# ### Keep select fields
#
# Keep only the fields for claim ID, procedure code, and diagnosis code.

# %%
df_select = df_claim_data[["claim_id", "procedure_code", "diagnosis_code"]]
df_select.sample(5)
# Out:
#        claim_id procedure_code diagnosis_code
# 218  3SH5BZYEI6          99221          A07.3
# 286  XRRAATHX7I          99238       S54.01XS
# 962  NHZOO9HJH4          99214       S62.212A
# 460  BCI8Z8GZAG          99213          A18.6
# 193  J0FY34DBL2          99214          A19.0
